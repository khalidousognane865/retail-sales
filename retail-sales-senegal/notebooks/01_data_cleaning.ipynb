# %% [markdown]
# # 01 - Nettoyage des données
# Chargement, exploration initiale et nettoyage du dataset Online Retail II.

# %%
import sys
sys.path.append('..')
import pandas as pd
from src.clean_data import load_raw_data, clean_data
from src.config import RAW_DATA_PATH, PROCESSED_DATA_PATH

# %% [markdown]
# ## 1. Chargement des données brutes

# %%
df = load_raw_data(RAW_DATA_PATH)
df.head()

# %%
df.info()

# %% [markdown]
# ## 2. Diagnostic qualité des données

# %%
print('Valeurs nulles par colonne :')
print(df.isnull().sum())
print('\nDoublons :', df.duplicated().sum())
print('\nQuantités négatives :', (df['Quantity'] < 0).sum())
print('Prix unitaires <= 0 :', (df['UnitPrice'] <= 0).sum())

# %% [markdown]
# ## 3. Nettoyage

# %%
df_clean = clean_data(df)
df_clean.head()

# %%
df_clean.to_csv(PROCESSED_DATA_PATH, index=False)
print(f'{len(df_clean):,} lignes sauvegardées dans {PROCESSED_DATA_PATH}')
